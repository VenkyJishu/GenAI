# %%
from gensim.models import Word2Vec,KeyedVectors
import gensim.downloader as api

# %%
wv_model = api.load('word2vec-google-news-300')

# %%
wv_model['Venky']
# Out:
# array([-0.10693359, -0.05273438, -0.24121094,  0.22167969,  0.12011719,
#         0.11816406,  0.43554688, -0.4609375 , -0.16992188,  0.18554688,
#         0.36523438, -0.25      ,  0.31835938,  0.37109375, -0.2734375 ,
#        -0.10839844, -0.44726562,  0.11230469,  0.14648438, -0.12109375,
#        -0.23242188, -0.18847656, -0.13769531, -0.0480957 ,  0.24023438,
#         0.26367188, -0.17089844, -0.4296875 ,  0.1171875 ,  0.38671875,
#        -0.8203125 ,  0.04223633, -0.19433594, -0.17480469, -0.16113281,
#         0.34570312,  0.24121094,  0.3046875 ,  0.42578125, -0.08691406,
#         0.23144531,  0.11035156, -0.95703125,  0.6640625 , -0.11230469,
#        -0.765625  ,  0.09960938,  0.18457031,  0.20507812, -0.06835938,
#        -0.03125   ,  0.01409912,  0.00549316,  0.0177002 , -0.27734375,
#        -0.26757812,  0.41015625, -0.14453125,  0.13867188, -0.31054688,
#        -0.10400391,  0.12597656, -0.51171875,  0.19238281, -0.390625  ,
# ...

# %%
wv_model['Venky'].shape
# Out:
# (300,)

# %%
wv_model['Jishu'].shape
# Out:
# (300,)

# %%
wv_model.most_similar('Venky')
# Out:
# [('Venkys', 0.7307903170585632),
#  ('Venkateshwara_Hatcheries', 0.6431133151054382),
#  ('Venkatesh_Rao', 0.6123311519622803),
#  ('owners_Venky', 0.6115118265151978),
#  ('Anuradha_Desai', 0.595302939414978),
#  ('chairman_Anuradha_Desai', 0.5736249685287476),
#  ('Saurin_Shah', 0.54892498254776),
#  ('giants_Venky', 0.5469621419906616),
#  ('giant_Venky', 0.5383298397064209),
#  ('Balaji_Rao', 0.5231078863143921)]

# %%
wv_model.most_similar('Jishu')
# Out:
# [('Thoda_Sa', 0.6813994646072388),
#  ('Happy_Husbands', 0.6760729551315308),
#  ('Naan_Avan_Illai', 0.6748537421226501),
#  ('Imsai_Arasan_##am_Pulikesi', 0.6748428344726562),
#  ('Parijatham', 0.6742172837257385),
#  ('Kadhali', 0.6733270883560181),
#  ('Gautam_Ghose', 0.6699585318565369),
#  ('Pournami', 0.6664741039276123),
#  ('Varai', 0.6654994487762451),
#  ('Naa_Raju', 0.6640024781227112)]

# %%
wv_model.most_similar('man','woman')
# Out:
# [('Shaun_Maloney_Aiden_McGeady', 0.35027220845222473),
#  ('tactically_adept', 0.3487197160720825),
#  ('Matt_Bramald', 0.3400961458683014),
#  ('strongside_LB', 0.337636798620224),
#  ('newboy', 0.33329278230667114),
#  ('Philip_Boampong', 0.33152341842651367),
#  ('joker', 0.3312978446483612),
#  ('superpest', 0.3302587866783142),
#  ('TRENDING_UP', 0.3300756514072418),
#  ('Felipe_Claybrooks', 0.3289523720741272)]

# %%
wv_model.similarity('man','woman')
# Out:
# 0.76640123

# %%
wv_model.similarity('man','son')
# Out:
# 0.425118

# %%
wv_model.similarity('father','son')
# Out:
# 0.8933086

# %%
wv_model.doesnt_match(['father','oracle','son','java','bus'])
# Out:
# 'bus'

# %%
vec = wv_model['king'] - wv_model['man'] + wv_model['woman']
wv_model.most_similar([vec])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]
